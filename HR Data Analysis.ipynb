# %% [markdown]
# Activities to complete:
#
# Data cleansing involves removing unnecessary columns.
#
# Giving the columns new names.
#
# Eliminating redundant entries.
#
# sanitizing specific columns.
#
# Eliminate the dataset's NaN values.
#
# Look for a few more changes if necessary

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('HR Data.csv')
data.head()
# Out:
#    Age Attrition BusinessTravel  DailyRate              Department  \
# 0   53        No  Travel_Rarely        102  Research & Development
# 1   28       Yes  Travel_Rarely        103  Research & Development
# 2   35       Yes  Travel_Rarely        104  Research & Development
# 3   39        No     Non-Travel        105  Research & Development
# 4   31        No  Travel_Rarely        106         Human Resources
#
#    DistanceFromHome  Education   EducationField  EmployeeCount  \
# 0                23          4    Life Sciences              1
# 1                24          3    Life Sciences              1
# 2                 2          3    Life Sciences              1
# 3                 9          3    Life Sciences              1
# 4                 2          3  Human Resources              1
#
#    EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0             901  ...                         3            80
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
#checking for null values
data.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#Dropping duplicates
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (1470, 35)

# %%
#Removing Unnessary columns
columns_to_drop = ['DailyRate', 'DistanceFromHome', 'EmployeeCount', 'MonthlyRate', 'Over18', 'StockOptionLevel', 'YearsWithCurrManager']
data.drop(columns=columns_to_drop, inplace=True)

# %%
data.rename(columns={
    'Age': 'age',
    'Attrition': 'attrition',
    'BusinessTravel': 'business_travel',
    'Department': 'department',
    'DistanceFromHome': 'distance_from_home',
    'Education': 'education',
    'EducationField': 'education_field',
    'EnvironmentSatisfaction': 'environment_satisfaction',
    'Gender': 'gender',
    'HourlyRate': 'hourly_rate',
    'JobInvolvement': 'job_involvement',
    'JobLevel': 'job_level',
    'JobRole': 'job_role',
    'JobSatisfaction': 'job_satisfaction',
    'MaritalStatus': 'marital_status',
    'MonthlyIncome': 'monthly_income',
    'NumCompaniesWorked': 'num_companies_worked',
    'OverTime': 'overtime',
    'PercentSalaryHike': 'percent_salary_hike',
    'PerformanceRating': 'performance_rating',
    'RelationshipSatisfaction': 'relationship_satisfaction',
    'TotalWorkingYears': 'total_working_years',
    'TrainingTimesLastYear': 'training_times_last_year',
    'WorkLifeBalance': 'work_life_balance',
    'YearsAtCompany': 'years_at_company',
    'YearsInCurrentRole': 'years_in_current_role',
    'YearsSinceLastPromotion': 'years_since_last_promotion'
}, inplace=True)

# %%
# Sanitize specific columns
data['department'] = data['department'].str.strip().str.lower()
data['education_field'] = data['education_field'].str.strip().str.lower()
data['job_role'] = data['job_role'].str.strip().str.lower()

# %%
data.head()
# Out:
#    age attrition business_travel              department  education  \
# 0   53        No   Travel_Rarely  research & development          4
# 1   28       Yes   Travel_Rarely  research & development          3
# 2   35       Yes   Travel_Rarely  research & development          3
# 3   39        No      Non-Travel  research & development          3
# 4   31        No   Travel_Rarely         human resources          3
#
#    education_field  EmployeeNumber  environment_satisfaction  gender  \
# 0    life sciences             901                         4  Female
# 1    life sciences              19                         3    Male
# 2    life sciences            1569                         1  Female
# 3    life sciences            2022                         4    Male
# 4  human resources             424                         1    Male
#
#    hourly_rate  ...  percent_salary_hike  performance_rating  \
# 0           72  ...                   18                   3
# ...
